# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import sys

import numpy as np

from nltk.tokenize import word_tokenize

from collections import Counter

import re

# %%
file = open('TomCabin.txt')
text = file.read()

# %%
#counts = Counter(adj_list)
sentences = nltk.sent_tokenize(text)
adj_list = []
#stopwords = set(STOPWORDS)
#stopwords.add("little")

#regex = r"-\d-"
#x = "-44-"
#re.sub(regex, "REMOVED", x)

for sentence in sentences:
    for word, pos in nltk.pos_tag(nltk.word_tokenize(str(sentence))):
        if (pos == 'JJ'):
            adj_list.append(word)
            count = Counter(adj_list)

count
# Out:
# Counter({'chilly': 1,
#          'well-furnished': 1,
#          'present': 32,
#          'great': 182,
#          'short': 60,
#          'thick-set': 2,
#          'low': 32,
#          'much': 127,
#          'over-dressed': 1,
#          'many': 140,
#          'blue': 18,
#          'yellow': 11,
#          'general': 38,
#          'large': 87,
#          'coarse': 6,
#          'heavy': 51,
#          'portentous': 2,
#          'evident': 14,
#          'free': 80,
#          'easy': 28,
#          'various': 53,
#          'graphic': 1,
#          'opulent': 3,
#          'earnest': 9,
#          'other': 206,
#          'uncommon': 10,
#          'worth': 13,
#          'steady': 8,
#          'capable': 6,
#          'whole': 111,
#          'tag=public': 466,
#          'part=all': 466,
#          '//www.saylor.org/courses/engl405/': 466,
#          'public': 479,
#          'good': 315,
#          'sensible': 8,
#          'pious': 28,
#          'true': 44,
#          'square': 6,
#          'candid': 1,
#          'fellow': 12,
#          'last': 191,
#          'gentle': 28,
#          'quiet': 38,
#          'valeyable': 1,
#          'genuine': 2,
#          'real': 40,
#          'Christian': 45,
#          'sure': 89,
#          'sorry': 24,
#          'little': 355,
#          'leetle': 5,
#          'hard': 59,
#          'uneasy': 12,
#          'willing': 23,
#          'small': 70,
#          'beautiful': 58,
#          'black': 96,
#          'fine': 46,
#          'glossy': 10,
#          'dark': 43,
#          'full': 75,
#          'rich': 12,
#          'long': 83,
#          'gay': 4,
#          '-44-': 1,
#          'certain': 30,
#          'comic': 3,
#          'unused': 1,
#          'curly': 5,
#          'wild': 32,
#          'grotesque': 2,
#          'common': 38,
#          'clear': 33,
#          'perfect': 24,
#          'old': 272,
#          'flexible': 3,
#          'childish': 9,
#          'doleful': 8,
#          'formidable': 1,
#          'imperturbable': 2,
#          'young': 160,
#          'Source': 6,
#          'open': 39,
#          'twenty-five': 2,
#          'same': 88,
#          'silky': 3,
#          'perceptible': 4,
#          'strange': 34,
#          'undisguised': 2,
#          'possible': 38,
#          'moulded': 1,
#          'trim': 2,
#          'quick': 19,
#          'ar': 17,
#          'fresh': 7,
#          'first': 91,
#          'such': 202,
#          'handsome': 23,
#          'comical': 1,
#          'musical': 4,
#          'mighty': 16,
#          'onpleasant': 3,
#          'new': 61,
#          'afraid': 20,
#          'white': 90,
#          '-47-': 1,
#          'confidential': 2,
#          'bad': 52,
#          'unfit': 1,
#          'high': 43,
#          'cold': 24,
#          'Clear': 1,
#          'virtuous': 5,
#          'second': 16,
#          'afresh': 1,
#          'few': 89,
#          'praisin': 1,
#          'likely': 19,
#          "pop'lar": 1,
#          'sir': 7,
#          'piquant': 2,
#          'original': 3,
#          'dear': 54,
#          'odd': 19,
#          'clever': 4,
#          'devil': 1,
#          'ridiculous': 7,
#          'natur': 5,
#          'sickly': 4,
#          'particular': 36,
#          'speak': 4,
#          'good-hearted': 1,
#          'fair': 34,
#          'goin': 1,
#          'clean': 16,
#          'rough': 14,
#          'tumble': 2,
#          'chop-fallen': 1,
#          'own': 195,
#          'happy': 32,
#          'slight': 5,
#          'disagreeable': 9,
#          'able': 13,
#          'impudent': 4,
#          'rascally': 1,
#          'thy': 36,
#          'agricultural': 1,
#          'gradual': 3,
#          'periodic': 2,
#          'southern': 15,
#          'healthful': 3,
#          'reasonable': 6,
#          'frail': 3,
#          'human': 45,
#          'sudden': 36,
#          'rapid': 4,
#          'unprotected': 2,
#          'good-humored': 2,
#          'oft-fabled': 1,
#          'poetic': 3,
#          'patriarchal': 1,
#          'hopeless': 6,
#          'impossible': 14,
#          'desirable': 1,
#          'regulated': 1,
#          'average': 1,
#          'physical': 10,
#          'to-day': 7,
#          '-52-': 1,
#          'poor': 215,
#          'proud': 15,
#          'confident': 1,
#          'natural': 24,
#          'moral': 20,
#          'religious': 21,
#          'practical': 8,
#          'unlimited': 2,
#          'decided': 8,
#          'extra': 6,
#          'shadowy': 4,
#          'foreseen': 1,
#          'sincere': 4,
#          'entire': 7,
#          'English': 5,
#          '1745-1826': 1,
#          'authoritative': 2,
#          'American': 11,
#          '-54-': 1,
#          'petted': 1,
#          'indulged': 1,
#          'south': 3,
#          'peculiar': 19,
#          'mulatto': 2,
#          'united': 1,
#          'dazzling': 1,
#          'personal': 16,
#          'agreeable': 12,
#          'fancy': 4,
#          'Safe': 1,
#          'fatal': 5,
#          'bright': 41,
#          'talented': 2,
#          'neighboring': 7,
#          'mechanical': 3,
#          'cotton-gin.1': 1,
#          'superior': 4,
#          'subject': 4,
#          'narrow-minded': 1,
#          'tyrannical': 7,
#          'intelligent': 5,
#          'valuable': 6,
#          'erect': 1,
#          'smart': 15,
#          'labor-saving': 1,
#          'irresistible': 2,
#          'bitter': 26,
#          'live': 7,
#          'dangerous': 10,
#          'disrespectful': 1,
#          'gloomy': 5,
#          'troubled': 4,
#          'indubitable': 2,
#          'womanly': 2,
#          'pleased': 10,
#          'bridal': 1,
#          'fairer': 1,
#          'infant': 1,
#          'sh': 1,
#          'intense': 6,
#          'maternal': 5,
#          'passionate': 7,
#          'tranquillized': 1,
#          'entwined': 1,
#          'sound': 4,
#          'legal': 10,
#          'former': 12,
#          '-58-': 1,
#          'smarting': 1,
#          'humane': 4,
#          '-59-': 1,
#          'glad': 26,
#          'neat': 7,
#          'shyly': 1,
#          'Surprised': 1,
#          'dreadful': 18,
#          'glorious': 10,
#          'miserable': 9,
#          'forlorn': 5,
#          'dead': 45,
#          'wicked': 22,
#          'patient': 11,
#          'Patient': 1,
#          'earthly': 12,
#          'humble': 11,
#          'careful': 21,
#          'flesh': 7,
#          'O': 2,
#          'busy': 33,
#          'pleasant': 11,
#          'right': 62,
#          'tremble': 1,
#          'fierce': 9,
#          'drowning': 1,
#          'mournful': 7,
#          'wrong': 20,
#          'deadly': 7,
#          'pale': 13,
#          'enough': 24,
#          'alive': 19,
#          '-66-': 1,
#          'native': 14,
#          'brilliant': 11,
#          'indulgent': 5,
#          'inferior': 1,
#          'ole': 4,
#          'anxious': 16,
#          'frizzling': 1,
#          'stew-pan': 1,
#          'grave': 6,
#          'bake-kettle': 2,
#          'well-starched': 4,
#          'checked': 3,
#          'latter': 5,
#          'numerous': 2,
#          'sublime': 11,
#          'practised': 2,
#          'fat': 11,
#          'honest': 4,
#          'fruitless': 2,
#          'welcome': 9,
#          'congenial': 1,
#          'snowy': 6,
#          'considerable': 11,
#          'upper': 15,
#          'distinguished': 1,
#          'scriptural': 2,
#          'woolly-headed': 2,
#          'successive': 3,
#          'rheumatic': 2,
#          'decidedly': 1,
#          'approaching': 1,
#          'powerfully-made': 1,
#          'truly': 1,
#          'African': 8,
#          'self-respecting': 1,
#          'dignified': 3,
#          'slate': 1,
#          'innumerable': 4,
#          'big': 11,
#          'dat': 22,
#          'final': 3,
#          'neatly-baked': 1,
#          'central': 1,
#          'mammy': 1,
#          'griddle': 2,
#          'dan': 1,
#          'facetious': 3,
#          'spile': 1,
#          'thin': 15,
#          'sharp': 19,
#          'light': 12,
#          'side': 2,
#          "'spectable": 1,
#          'Good': 9,
#          'nothin': 20,
#          'dem': 4,
#          'pretty': 21,
#          'flecky': 1,
#          'nice': 12,
#          'innocent': 7,
#          'ye': 15,
#          'yer': 25,
#          'hearty': 2,
#          'fit': 2,
#          'sanguinary': 1,
#          'till': 6,
#          'witty': 1,
#          'funny': 7,
#          '-72-': 1,
#          'telled': 1,
#          'benevolent': 3,
#          'benighted': 2,
#          'strong': 51,
#          'oughtenter': 1,
#          'gi': 1,
#          'serious': 16,
#          'next': 37,
#          'Wo': 1,
#          'dey': 4,
#          'jist': 4,
#          'de': 10,
#          'sarcy': 2,
#          '-73-': 1,
#          'hern': 1,
#          'whar': 2,
#          "dinin'-room": 1,
#          'orter': 1,
#          'opposite': 7,
#          'liberal': 2,
#          'comfortable': 15,
#          '-74-': 1,
#          'obstreperous': 1,
#          'decent': 9,
#          'button-hole': 1,
#          'terrible': 9,
#          'difficult': 7,
#          'awful': 22,
#          'vigorous': 4,
#          'wid': 2,
#          'woolly': 4,
#          'clar': 8,
#          'cracked': 2,
#          'special': 6,
#          'full-length': 1,
#          'broad': 16,
#          'like': 4,
#          'surgical': 2,
#          'daily': 16,
#          'trundle-bed': 1,
#          'curis': 2,
#          'rude': 8,
#          'mebbe': 1,
#          'weekly': 1,
#          'indefinite': 8,
#          'nigh': 2,
#          'nasal': 2,
#          'failin': 1,
#          'empty': 5,
#          'interestin': 1,
#          'ready': 32,
#          'gray-headed': 3,
#          'harmless': 1,
#          'red': 9,
#          'gown': 1,
#          'well-known': 5,
#          'golden': 29,
#          'incessant': 2,
#          'imaginative': 2,
#          'pictorial': 1,
#          'Various': 2,
#          'bundle': 2,
#          'wonderful': 9,
#          'commendable': 3,
#          "'mazin": 1,
#          'predominant': 3,
#          'child-like': 3,
#          'devotional': 1,
#          'afore-named': 3,
#          'well-worn': 1,
#          'suppressed': 2,
#          'solitary': 2,
#          '-81-': 1,
#          'complicated': 1,
#          'haggard': 2,
#          'low-bred': 1,
#          'dinner-table': 2,
#          'intent': 2,
#          'bottom': 1,
#          'Impossible': 1,
#          'faithful': 22,
#          'only': 30,
#          'forgive': 2,
#          'hasty': 6,
#          'unprepared': 1,
#          'noble-hearted': 2,
#          'pecuniary': 2,
#          'simple': 29,
#          'dependent': 1,
#          'excellent': 3,
#          'confiding': 1,
#          'unprincipled': 1,
#          'round': 3,
#          'accursed': 2,
#          'slave': 5,
#          'exact': 9,
#          'expensive': 2,
#          'thankful': 5,
#          'narrow': 5,
#          'unrelenting': 2,
#          'early': 20,
#          'cruel': 10,
#          'outer': 2,
#          'feverish': 5,
#          'excited': 3,
#          'rigid': 1,
#          'compressed': 1,
#          'soft': 32,
#          'timid': 4,
#          'mute': 1,
#          'sat': 2,
#          'unconscious': 7,
#          'rosy': 5,
#          'smile': 1,
#          'ungrateful': 3,
#          'favorite': 6,
#          'unusual': 3,
#          'loud': 15,
#          'ugly': 2,
#          'frosty': 4,
#          'star-light': 1,
#          'close': 7,
#          'vague': 4,
#          'dim': 6,
#          'late': 10,
#          'lengthy': 1,
#          'worthy': 11,
#          'asleep': 5,
#          'gwine': 6,
#          'skeered': 1,
#          'sick': 30,
#          '-90-': 1,
#          'sigh': 1,
#          'used': 2,
#          'hoarse': 2,
#          '-91-': 1,
#          'first-born': 1,
#          'knew': 1,
#          'husky': 1,
#          '-92-': 1,
#          'protracted': 1,
#          'usual': 24,
#          'colored': 13,
#          'wide': 17,
#          'different': 24,
#          'silent': 33,
#          'joyous': 3,
#          'ill': 6,
#          'rael': 2,
#          'immeasurable': 3,
#          'withered': 1,
#          'triumphant': 5,
#          'indescribable': 3,
#          'unfortunate': 6,
#          "extro'rnary": 1,
#          "sing'lar": 1,
#          'plaguy': 2,
#          'unceremonious': 2,
#          'ordinary': 9,
#          'goodnatured': 2,
#          'breakfast-table': 3,
#          'respectable': 22,
#          'above': 1,
#          'familiar': 11,
#          'Devilish': 1,
#          'grand': 8,
#          'prime': 3,
#          'probable': 3,
#          'unprecedented': 1,
#          'strict': 2,
#          '-96-': 1,
#          'additional': 1,
#          'boots': 1,
#          'High': 5,
#          'infinite': 3,
#          'heap': 4,
#          'green': 8,
#          'o': 4,
#          'dese': 5,
#          'URL': 3,
#          'profound': 3,
#          'regularly': 1,
#          'mental': 5,
#          'dis': 7,
#          'skittish': 1,
#          'curious': 6,
#          'mischievous': 3,
#          'beech-tree': 1,
#          'triangular': 1,
#          'weight': 1,
#          'nervous': 22,
#          'fix': 1,
#          'vacant': 3,
#          'fur': 2,
#          'ludicrous': 7,
#          'surprised': 6,
#          'suggestive': 1,
#          'instant': 6,
#          "or'nary": 2,
#          "caperin'": 1,
#          'contrary': 7,
#          'immoderate': 2,
#          'exquisite': 3,
#          'fragmentary': 1,
#          'upright': 4,
#          'equal': 16,
#          'dexterous': 1,
#          'mettlesome': 1,
#          'dry': 15,
#          'frantic': 2,
#          'palm-leaf': 2,
#          'contemptuous': 6,
#          'loose': 5,
#          'direful': 1,
#          'miscellaneous': 3,
#          'outrageous': 4,
#          'untiring': 1,
#          'fleet': 1,
#          'spirited': 2,
#          'flashing': 1,
#          'cotched': 1,
#          'amiable': 3,
#          'cursed': 6,
#          'equivocal': 1,
#          'unutterable': 2,
#          'mad': 2,
#          "'portant": 1,
#          '-104-': 1,
#          'desolate': 3,
#          'confused': 8,
#          'stunning': 1,
#          'near': 2,
#          'fearful': 13,
#          'indifferent': 4,
#          'convulsive': 4,
#          '-105-': 1,
#          'supernatural': 5,
#          'frequent': 4,
#          'brutal': 17,
#          'brief': 4,
#          'sleepy': 2,
#          'repressed': 4,
#          'weary': 23,
#          'warm': 10,
#          'electric': 3,
#          'impregnable': 3,
#          'weak': 10,
#          'hurried': 3,
#          'alert': 4,
#          'aware': 3,
#          'headlong': 2,
#          'half-mile': 1,
#          'thick': 6,
#          'wondered': 1,
#          'safe': 14,
#          'unlikely': 1,
#          'fugitive': 5,
#          'critical': 4,
#          'unsuspected': 1,
#          'hungry': 6,
#          'foot-sore': 1,
#          'turbulent': 1,
#          'temporary': 4,
#          'undulating': 4,
#          'unfavorable': 1,
#          'plaintive': 1,
#          'onlucky': 1,
#          'motherly': 3,
#          'dirty': 9,
#          'to-night': 14,
#          'sweet': 13,
#          'dignitary': 1,
#          'gruff': 3,
#          'leisurely': 1,
#          'circumstantial': 1,
#          'singular': 11,
#          'due': 5,
#          'dogged': 3,
#          'raw': 5,
#          'oneasy': 3,
#          'wus': 1,
#          'uplifted': 1,
#          'sayin': 1,
#          "dre'ful": 1,
#          'wish': 10,
#          'tear': 5,
#          'jest': 2,
#          'tough': 2,
#          "'d": 1,
#          'acquiescent': 1,
#          'feared': 1,
#          '-112-': 1,
#          'powerful': 6,
#          "o'": 2,
#          'straight': 7,
#          'overcome': 4,
#          'absolute': 7,
#          'sordid': 1,
#          'insensible': 5,
#          'female': 7,
#          'zealous': 4,
#          'eminent': 1,
#          'desperate': 13,
#          'considable': 1,
#          'hang': 2,
#          'seris': 1,
#          'geographical': 2,
#          'vehement': 4,
#          'travelled': 1,
#          'suspicious': 1,
#          'cussed': 5,
#          'reflective': 3,
#          'appeared': 1,
#          'lonesome': 3,
#          'pecular': 1,
#          'sartin': 1,
#          't': 1,
#          'private': 8,
#          'generic': 2,
#          'despit': 1,
#          'noncommittal': 1,
#          'involuntary': 3,
#          'unwilling': 3,
#          'dutiful': 1,
#          "desp't": 1,
#          'give': 2,
#          'rueful': 2,
#          'explosive': 3,
#          'brisk': 4,
#          'distant': 14,
#          'craggy': 1,
#          'constant': 11,
#          'tumultuous': 2,
#          'barn-yard': 1,
#          'injured': 2,
#          'unlucky': 3,
#          'characteristic': 9,
#          'front': 2,
#          'dizzy': 2,
#          'turbid': 3,
#          'current': 7,
#          'huge': 1,
#          'pitched': 1,
#          'brave': 3,
#          'steep': 4,
#          'main': 2,
#          'neighborly': 1,
#          'agin': 4,
#          'heathenish': 3,
#          'constitutional': 1,
#          'enlightened': 2,
#          'tolable': 1,
#          'curi': 1,
#          '-120-': 1,
#          'Good-evening': 1,
#          '-121-': 1,
#          'gray': 7,
#          'swollen': 1,
#          'floundering': 1,
#          'tavern': 5,
#          'further': 6,
#          'shining': 1,
#          'sundry': 4,
#          'high-backed': 2,
#          'dimly-smoking': 1,
#          'happiness': 1,
#          'select': 1,
#          'dissonant': 1,
#          'call': 1,
#          'muscular': 4,
#          'lineament': 1,
#          'unhesitating': 1,
#          'bull-dog': 1,
#          'unapt': 3,
#          'travelling': 1,
#          'keen': 7,
#          'eager': 2,
#          'cautious': 3,
#          'tip-toe': 1,
#          'quivering': 1,
#          'complacent': 1,
#          'well-advised': 1,
#          'come': 2,
#          'civil': 1,
#          'hobble': 1,
#          'hot': 16,
#          'pathetic': 10,
#          'surly': 4,
#          'nose': 2,
#          'chin': 1,
#          'internal': 2,
#          'young-un': 1,
#          'l': 2,
#          "mis'able": 2,
#          'gin': 1,
#          "'cause": 1,
#          'Last': 8,
#          'child': 5,
#          'stone': 2,
#          'cotton-bale': 2,
#          'ill-repressed': 2,
#          "'em": 1,
#          'affable': 1,
#          'consistent': 2,
#          'doggish': 1,
#          'similar': 5,
#          'fust': 1,
#          'tight': 3,
#          'snug': 1,
#          'necessary': 20,
#          'cross': 1,
#          'feelin': 1,
#          "p'isin": 1,
#          'professional': 1,
#          'hundred': 5,
#          'n': 2,
#          'relishin': 1,
#          'slow': 11,
#          'ten': 10,
#          'tremendous': 3,
#          'Suppose': 1,
#          'quite': 4,
#          'fifty': 8,
#          'flat': 9,
#          'sixteen': 3,
#          'onreasonable': 1,
#          'bush-whacking': 1,
#          'conciliatory': 3,
#          'good-natured': 11,
#          'greasy': 5,
#          'boy': 1,
#          'somewhere': 1,
#          "it's": 1,
#          'underground': 1,
#          'First': 1,
#          'shawl': 1,
#          'lucky': 1,
#          'visible': 1,
#          'lawful': 5,
#          'patriotic': 3,
#          'locomotive': 1,
#          'nineteenth': 1,
#          'high-sounding': 1,
#          'drefful': 5,
#          "'Hio": 2,
#          'uncommonly': 3,
#          'responsible': 2,
#          'hear': 2,
#          'Easy': 1,
#          "t'": 1,
#          'angry': 4,
#          'penitential': 1,
#          "l'man": 1,
#          'proper': 10,
#          'intimated': 1,
#          'political': 7,
#          'especial': 4,
#          'rakish': 1,
#          'free-and-easy': 4,
#          'apparent': 5,
#          'ancient': 4,
#          'chronic': 3,
#          'obvious': 2,
#          'persecuted': 2,
#          'prodigal': 1,
#          'conceivable': 1,
#          'mathematical': 1,
#          'picturesque': 2,
#          'fashionable': 4,
#          'immovable': 1,
#          'sententious': 1,
#          'rebuked': 1,
#          'youngerly': 2,
#          'sot': 3,
#          'enthusiastic': 2,
#          "what's": 1,
#          'persistent': 4,
#          'folks': 2,
#          'top': 4,
#          'contrar': 1,
#          'ary': 1,
#          'restive': 1,
#          'feller-citizens': 1,
#          'principle': 1,
#          'scase': 1,
#          '-141-': 1,
#          'cheerful': 9,
#          'well-brightened': 1,
#          'senatorial': 1,
#          'very': 1,
#          'admonitory': 1,
#          'frolicsome': 1,
#          'untold': 4,
#          'door-knob': 1,
#          'Mary': 5,
#          'tired': 7,
#          'half-open': 1,
#          'tiresome': 3,
#          'downright': 3,
#          'unchristian': 4,
#          'reckless': 1,
#          'mild': 3,
#          'peach-blow': 1,
#          'sweetest': 1,
#          'moderate-sized': 1,
#          'moderate': 3,
#          'unusually': 1,
#          'sympathetic': 3,
#          'alarming': 1,
#          'inexplicable': 2,
#          'reverent': 1,
#          'several': 18,
#          'graceless': 1,
#          'crazy': 1,
#          'determined': 2,
#          'shameful': 4,
#          'abominable': 6,
#          'interesting': 5,
#          'naked': 7,
#          'accessible': 1,
#          'indefensible': 1,
#          'defenceless': 3,
#          'painful': 6,
#          'duty-it': 1,
#          '-146-': 1,
#          'whimsical': 1,
#          'slender': 2,
#          'torn': 3,
#          'frozen': 3,
#          'despised': 2,
#          'aspect': 1,
#          'domestic': 14,
#          'restorative': 1,
#          'Sure': 2,
#          "tol'able": 5,
#          'a-askin': 1,
#          'unrelaxing': 1,
#          'vigilant': 1,
#          'rested': 1,
#          'awake': 3,
#          'heart-broken': 6,
#          'agitated': 2,
#          'To-night': 3,
#          'deep': 32,
#          'unexpected': 1,
#          'pocket-handkerchiefs': 1,
#          'wry': 1,
#          'grown': 1,
#          'superficial': 1,
#          'apathetic': 1,
#          'Pish': 1,
#          'to-morrow': 7,
#          'fish': 1,
#          'confounded': 2,
#          'liege': 1,
#          "lord's": 1,
#          'cheap': 1,
#          'bed-room': 1,
#          'significant': 3,
#          'worn': 5,
#          'toy': 1,
#          'heart-break': 2,
#          'substantial': 2,
#          'sorrowful': 3,
#          'distressed': 6,
#          'delicate': 7,
#          'lost': 3,
#          'outcast': 1,
#          'serviceable': 1,
#          'work-table': 1,
#          'needle': 2,
#          'thimble': 3,
#          'twelve': 1,
#          'stringent': 1,
#          'immortal': 13,
#          'sentimental': 1,
#          'bold': 13,
#          '-156-': 1,
#          'imploring': 2,
#          'sad': 15,
#          'noble': 17,
#          'generous': 14,
#          'honorable': 3,
#          'continuous': 2,
#          'eastern': 2,
#          'unfathomable': 1,
#          'es': 1,
#          'accurate': 1,
#          'down-hill': 1,
#          'ineffectual': 2,
#          'outside': 2,
#          'back': 11,
#          'incredible': 2,
#          'firm': 2,
#          'despairing': 2,
#          'Western': 1,
#          'respectful': 7,
#          'inconsiderable': 1,
#          'tall': 15,
#          'sandy': 3,
#          'tousled': 1,
#          'dismal': 1,
#          'mystified': 1,
#          'gigantic': 5,
#          'retired': 2,
#          'Weary': 1,
#          'gal': 2,
#          'goodly': 5,
#          'healthy': 7,
#          "havin'": 1,
#          'ere': 1,
#          'Greek': 3,
#          'frisky': 1,
#          'ten-dollar': 1,
#          '-162-': 1,
#          'table': 3,
#          'ironing-cloth': 1,
#          'scrupulous': 5,
#          'unhappy': 5,
#          'smooth': 7,
#          "S'pose": 1,
#          'thine': 1,
#          'thar': 3,
#          '-164-': 1,
#          'stubborn': 1,
#          'sparrow': 1,
#          'instinctive': 5,
#          'local': 1,
#          'unknown': 8,
#          'unaffected': 2,
#          'frightful': 8,
#          '-165-': 1,
#          'missionary': 9,
#          'unenterprising': 1,
#          'heroic': 3,
#          'dread': 4,
#          "husband's": 1,
#          'mysterious': 12,
#          'extreme': 2,
#          'tossed': 1,
#          'act': 1,
#          'imperious': 3,
#          'utmost': 4,
#          'clamorous': 1,
#          'averted': 2,
#          'smothered': 6,
#          'unnecessary': 2,
#          'driving': 1,
#          "wife's": 1,
#          'half-slumbering': 1,
#          'manly': 2,
#          'unpleasant': 3,
#          'dusty': 3,
#          'past': 16,
#          '-170-': 1,
#          'stupid': 4,
#          'drunken': 3,
#          'sugar': 1,
#          'nasty': 1,
#          'mean': 10,
#          ...})

# %%
count = Counter(count)
max_threshold = 22
c = {y: count for y, count in count.items() if count <= max_threshold}
c
# Out:
# {'chilly': 1,
#  'well-furnished': 1,
#  'thick-set': 2,
#  'over-dressed': 1,
#  'blue': 18,
#  'yellow': 11,
#  'coarse': 6,
#  'portentous': 2,
#  'evident': 14,
#  'graphic': 1,
#  'opulent': 3,
#  'earnest': 9,
#  'uncommon': 10,
#  'worth': 13,
#  'steady': 8,
#  'capable': 6,
#  'sensible': 8,
#  'square': 6,
#  'candid': 1,
#  'fellow': 12,
#  'valeyable': 1,
#  'genuine': 2,
#  'leetle': 5,
#  'uneasy': 12,
#  'glossy': 10,
#  'rich': 12,
#  'gay': 4,
#  '-44-': 1,
#  'comic': 3,
#  'unused': 1,
#  'curly': 5,
#  'grotesque': 2,
#  'flexible': 3,
#  'childish': 9,
#  'doleful': 8,
#  'formidable': 1,
#  'imperturbable': 2,
#  'Source': 6,
#  'twenty-five': 2,
#  'silky': 3,
#  'perceptible': 4,
#  'undisguised': 2,
#  'moulded': 1,
#  'trim': 2,
#  'quick': 19,
#  'ar': 17,
#  'fresh': 7,
#  'comical': 1,
#  'musical': 4,
#  'mighty': 16,
#  'onpleasant': 3,
#  'afraid': 20,
#  '-47-': 1,
#  'confidential': 2,
#  'unfit': 1,
#  'Clear': 1,
#  'virtuous': 5,
#  'second': 16,
#  'afresh': 1,
#  'praisin': 1,
#  'likely': 19,
#  "pop'lar": 1,
#  'sir': 7,
#  'piquant': 2,
#  'original': 3,
#  'odd': 19,
#  'clever': 4,
#  'devil': 1,
#  'ridiculous': 7,
#  'natur': 5,
#  'sickly': 4,
#  'speak': 4,
#  'good-hearted': 1,
#  'goin': 1,
#  'clean': 16,
#  'rough': 14,
#  'tumble': 2,
#  'chop-fallen': 1,
#  'slight': 5,
#  'disagreeable': 9,
#  'able': 13,
#  'impudent': 4,
#  'rascally': 1,
#  'agricultural': 1,
#  'gradual': 3,
#  'periodic': 2,
#  'southern': 15,
#  'healthful': 3,
#  'reasonable': 6,
#  'frail': 3,
#  'rapid': 4,
#  'unprotected': 2,
#  'good-humored': 2,
#  'oft-fabled': 1,
#  'poetic': 3,
#  'patriarchal': 1,
#  'hopeless': 6,
#  'impossible': 14,
#  'desirable': 1,
#  'regulated': 1,
#  'average': 1,
#  'physical': 10,
#  'to-day': 7,
#  '-52-': 1,
#  'proud': 15,
#  'confident': 1,
#  'moral': 20,
#  'religious': 21,
#  'practical': 8,
#  'unlimited': 2,
#  'decided': 8,
#  'extra': 6,
#  'shadowy': 4,
#  'foreseen': 1,
#  'sincere': 4,
#  'entire': 7,
#  'English': 5,
#  '1745-1826': 1,
#  'authoritative': 2,
#  'American': 11,
#  '-54-': 1,
#  'petted': 1,
#  'indulged': 1,
#  'south': 3,
#  'peculiar': 19,
#  'mulatto': 2,
#  'united': 1,
#  'dazzling': 1,
#  'personal': 16,
#  'agreeable': 12,
#  'fancy': 4,
#  'Safe': 1,
#  'fatal': 5,
#  'talented': 2,
#  'neighboring': 7,
#  'mechanical': 3,
#  'cotton-gin.1': 1,
#  'superior': 4,
#  'subject': 4,
#  'narrow-minded': 1,
#  'tyrannical': 7,
#  'intelligent': 5,
#  'valuable': 6,
#  'erect': 1,
#  'smart': 15,
#  'labor-saving': 1,
#  'irresistible': 2,
#  'live': 7,
#  'dangerous': 10,
#  'disrespectful': 1,
#  'gloomy': 5,
#  'troubled': 4,
#  'indubitable': 2,
#  'womanly': 2,
#  'pleased': 10,
#  'bridal': 1,
#  'fairer': 1,
#  'infant': 1,
#  'sh': 1,
#  'intense': 6,
#  'maternal': 5,
#  'passionate': 7,
#  'tranquillized': 1,
#  'entwined': 1,
#  'sound': 4,
#  'legal': 10,
#  'former': 12,
#  '-58-': 1,
#  'smarting': 1,
#  'humane': 4,
#  '-59-': 1,
#  'neat': 7,
#  'shyly': 1,
#  'Surprised': 1,
#  'dreadful': 18,
#  'glorious': 10,
#  'miserable': 9,
#  'forlorn': 5,
#  'wicked': 22,
#  'patient': 11,
#  'Patient': 1,
#  'earthly': 12,
#  'humble': 11,
#  'careful': 21,
#  'flesh': 7,
#  'O': 2,
#  'pleasant': 11,
#  'tremble': 1,
#  'fierce': 9,
#  'drowning': 1,
#  'mournful': 7,
#  'wrong': 20,
#  'deadly': 7,
#  'pale': 13,
#  'alive': 19,
#  '-66-': 1,
#  'native': 14,
#  'brilliant': 11,
#  'indulgent': 5,
#  'inferior': 1,
#  'ole': 4,
#  'anxious': 16,
#  'frizzling': 1,
#  'stew-pan': 1,
#  'grave': 6,
#  'bake-kettle': 2,
#  'well-starched': 4,
#  'checked': 3,
#  'latter': 5,
#  'numerous': 2,
#  'sublime': 11,
#  'practised': 2,
#  'fat': 11,
#  'honest': 4,
#  'fruitless': 2,
#  'welcome': 9,
#  'congenial': 1,
#  'snowy': 6,
#  'considerable': 11,
#  'upper': 15,
#  'distinguished': 1,
#  'scriptural': 2,
#  'woolly-headed': 2,
#  'successive': 3,
#  'rheumatic': 2,
#  'decidedly': 1,
#  'approaching': 1,
#  'powerfully-made': 1,
#  'truly': 1,
#  'African': 8,
#  'self-respecting': 1,
#  'dignified': 3,
#  'slate': 1,
#  'innumerable': 4,
#  'big': 11,
#  'dat': 22,
#  'final': 3,
#  'neatly-baked': 1,
#  'central': 1,
#  'mammy': 1,
#  'griddle': 2,
#  'dan': 1,
#  'facetious': 3,
#  'spile': 1,
#  'thin': 15,
#  'sharp': 19,
#  'light': 12,
#  'side': 2,
#  "'spectable": 1,
#  'Good': 9,
#  'nothin': 20,
#  'dem': 4,
#  'pretty': 21,
#  'flecky': 1,
#  'nice': 12,
#  'innocent': 7,
#  'ye': 15,
#  'hearty': 2,
#  'fit': 2,
#  'sanguinary': 1,
#  'till': 6,
#  'witty': 1,
#  'funny': 7,
#  '-72-': 1,
#  'telled': 1,
#  'benevolent': 3,
#  'benighted': 2,
#  'oughtenter': 1,
#  'gi': 1,
#  'serious': 16,
#  'Wo': 1,
#  'dey': 4,
#  'jist': 4,
#  'de': 10,
#  'sarcy': 2,
#  '-73-': 1,
#  'hern': 1,
#  'whar': 2,
#  "dinin'-room": 1,
#  'orter': 1,
#  'opposite': 7,
#  'liberal': 2,
#  'comfortable': 15,
#  '-74-': 1,
#  'obstreperous': 1,
#  'decent': 9,
#  'button-hole': 1,
#  'terrible': 9,
#  'difficult': 7,
#  'awful': 22,
#  'vigorous': 4,
#  'wid': 2,
#  'woolly': 4,
#  'clar': 8,
#  'cracked': 2,
#  'special': 6,
#  'full-length': 1,
#  'broad': 16,
#  'like': 4,
#  'surgical': 2,
#  'daily': 16,
#  'trundle-bed': 1,
#  'curis': 2,
#  'rude': 8,
#  'mebbe': 1,
#  'weekly': 1,
#  'indefinite': 8,
#  'nigh': 2,
#  'nasal': 2,
#  'failin': 1,
#  'empty': 5,
#  'interestin': 1,
#  'gray-headed': 3,
#  'harmless': 1,
#  'red': 9,
#  'gown': 1,
#  'well-known': 5,
#  'incessant': 2,
#  'imaginative': 2,
#  'pictorial': 1,
#  'Various': 2,
#  'bundle': 2,
#  'wonderful': 9,
#  'commendable': 3,
#  "'mazin": 1,
#  'predominant': 3,
#  'child-like': 3,
#  'devotional': 1,
#  'afore-named': 3,
#  'well-worn': 1,
#  'suppressed': 2,
#  'solitary': 2,
#  '-81-': 1,
#  'complicated': 1,
#  'haggard': 2,
#  'low-bred': 1,
#  'dinner-table': 2,
#  'intent': 2,
#  'bottom': 1,
#  'Impossible': 1,
#  'faithful': 22,
#  'forgive': 2,
#  'hasty': 6,
#  'unprepared': 1,
#  'noble-hearted': 2,
#  'pecuniary': 2,
#  'dependent': 1,
#  'excellent': 3,
#  'confiding': 1,
#  'unprincipled': 1,
#  'round': 3,
#  'accursed': 2,
#  'slave': 5,
#  'exact': 9,
#  'expensive': 2,
#  'thankful': 5,
#  'narrow': 5,
#  'unrelenting': 2,
#  'early': 20,
#  'cruel': 10,
#  'outer': 2,
#  'feverish': 5,
#  'excited': 3,
#  'rigid': 1,
#  'compressed': 1,
#  'timid': 4,
#  'mute': 1,
#  'sat': 2,
#  'unconscious': 7,
#  'rosy': 5,
#  'smile': 1,
#  'ungrateful': 3,
#  'favorite': 6,
#  'unusual': 3,
#  'loud': 15,
#  'ugly': 2,
#  'frosty': 4,
#  'star-light': 1,
#  'close': 7,
#  'vague': 4,
#  'dim': 6,
#  'late': 10,
#  'lengthy': 1,
#  'worthy': 11,
#  'asleep': 5,
#  'gwine': 6,
#  'skeered': 1,
#  '-90-': 1,
#  'sigh': 1,
#  'used': 2,
#  'hoarse': 2,
#  '-91-': 1,
#  'first-born': 1,
#  'knew': 1,
#  'husky': 1,
#  '-92-': 1,
#  'protracted': 1,
#  'colored': 13,
#  'wide': 17,
#  'joyous': 3,
#  'ill': 6,
#  'rael': 2,
#  'immeasurable': 3,
#  'withered': 1,
#  'triumphant': 5,
#  'indescribable': 3,
#  'unfortunate': 6,
#  "extro'rnary": 1,
#  "sing'lar": 1,
#  'plaguy': 2,
#  'unceremonious': 2,
#  'ordinary': 9,
#  'goodnatured': 2,
#  'breakfast-table': 3,
#  'respectable': 22,
#  'above': 1,
#  'familiar': 11,
#  'Devilish': 1,
#  'grand': 8,
#  'prime': 3,
#  'probable': 3,
#  'unprecedented': 1,
#  'strict': 2,
#  '-96-': 1,
#  'additional': 1,
#  'boots': 1,
#  'High': 5,
#  'infinite': 3,
#  'heap': 4,
#  'green': 8,
#  'o': 4,
#  'dese': 5,
#  'URL': 3,
#  'profound': 3,
#  'regularly': 1,
#  'mental': 5,
#  'dis': 7,
#  'skittish': 1,
#  'curious': 6,
#  'mischievous': 3,
#  'beech-tree': 1,
#  'triangular': 1,
#  'weight': 1,
#  'nervous': 22,
#  'fix': 1,
#  'vacant': 3,
#  'fur': 2,
#  'ludicrous': 7,
#  'surprised': 6,
#  'suggestive': 1,
#  'instant': 6,
#  "or'nary": 2,
#  "caperin'": 1,
#  'contrary': 7,
#  'immoderate': 2,
#  'exquisite': 3,
#  'fragmentary': 1,
#  'upright': 4,
#  'equal': 16,
#  'dexterous': 1,
#  'mettlesome': 1,
#  'dry': 15,
#  'frantic': 2,
#  'palm-leaf': 2,
#  'contemptuous': 6,
#  'loose': 5,
#  'direful': 1,
#  'miscellaneous': 3,
#  'outrageous': 4,
#  'untiring': 1,
#  'fleet': 1,
#  'spirited': 2,
#  'flashing': 1,
#  'cotched': 1,
#  'amiable': 3,
#  'cursed': 6,
#  'equivocal': 1,
#  'unutterable': 2,
#  'mad': 2,
#  "'portant": 1,
#  '-104-': 1,
#  'desolate': 3,
#  'confused': 8,
#  'stunning': 1,
#  'near': 2,
#  'fearful': 13,
#  'indifferent': 4,
#  'convulsive': 4,
#  '-105-': 1,
#  'supernatural': 5,
#  'frequent': 4,
#  'brutal': 17,
#  'brief': 4,
#  'sleepy': 2,
#  'repressed': 4,
#  'warm': 10,
#  'electric': 3,
#  'impregnable': 3,
#  'weak': 10,
#  'hurried': 3,
#  'alert': 4,
#  'aware': 3,
#  'headlong': 2,
#  'half-mile': 1,
#  'thick': 6,
#  'wondered': 1,
#  'safe': 14,
#  'unlikely': 1,
#  'fugitive': 5,
#  'critical': 4,
#  'unsuspected': 1,
#  'hungry': 6,
#  'foot-sore': 1,
#  'turbulent': 1,
#  'temporary': 4,
#  'undulating': 4,
#  'unfavorable': 1,
#  'plaintive': 1,
#  'onlucky': 1,
#  'motherly': 3,
#  'dirty': 9,
#  'to-night': 14,
#  'sweet': 13,
#  'dignitary': 1,
#  'gruff': 3,
#  'leisurely': 1,
#  'circumstantial': 1,
#  'singular': 11,
#  'due': 5,
#  'dogged': 3,
#  'raw': 5,
#  'oneasy': 3,
#  'wus': 1,
#  'uplifted': 1,
#  'sayin': 1,
#  "dre'ful": 1,
#  'wish': 10,
#  'tear': 5,
#  'jest': 2,
#  'tough': 2,
#  "'d": 1,
#  'acquiescent': 1,
#  'feared': 1,
#  '-112-': 1,
#  'powerful': 6,
#  "o'": 2,
#  'straight': 7,
#  'overcome': 4,
#  'absolute': 7,
#  'sordid': 1,
#  'insensible': 5,
#  'female': 7,
#  'zealous': 4,
#  'eminent': 1,
#  'desperate': 13,
#  'considable': 1,
#  'hang': 2,
#  'seris': 1,
#  'geographical': 2,
#  'vehement': 4,
#  'travelled': 1,
#  'suspicious': 1,
#  'cussed': 5,
#  'reflective': 3,
#  'appeared': 1,
#  'lonesome': 3,
#  'pecular': 1,
#  'sartin': 1,
#  't': 1,
#  'private': 8,
#  'generic': 2,
#  'despit': 1,
#  'noncommittal': 1,
#  'involuntary': 3,
#  'unwilling': 3,
#  'dutiful': 1,
#  "desp't": 1,
#  'give': 2,
#  'rueful': 2,
#  'explosive': 3,
#  'brisk': 4,
#  'distant': 14,
#  'craggy': 1,
#  'constant': 11,
#  'tumultuous': 2,
#  'barn-yard': 1,
#  'injured': 2,
#  'unlucky': 3,
#  'characteristic': 9,
#  'front': 2,
#  'dizzy': 2,
#  'turbid': 3,
#  'current': 7,
#  'huge': 1,
#  'pitched': 1,
#  'brave': 3,
#  'steep': 4,
#  'main': 2,
#  'neighborly': 1,
#  'agin': 4,
#  'heathenish': 3,
#  'constitutional': 1,
#  'enlightened': 2,
#  'tolable': 1,
#  'curi': 1,
#  '-120-': 1,
#  'Good-evening': 1,
#  '-121-': 1,
#  'gray': 7,
#  'swollen': 1,
#  'floundering': 1,
#  'tavern': 5,
#  'further': 6,
#  'shining': 1,
#  'sundry': 4,
#  'high-backed': 2,
#  'dimly-smoking': 1,
#  'happiness': 1,
#  'select': 1,
#  'dissonant': 1,
#  'call': 1,
#  'muscular': 4,
#  'lineament': 1,
#  'unhesitating': 1,
#  'bull-dog': 1,
#  'unapt': 3,
#  'travelling': 1,
#  'keen': 7,
#  'eager': 2,
#  'cautious': 3,
#  'tip-toe': 1,
#  'quivering': 1,
#  'complacent': 1,
#  'well-advised': 1,
#  'come': 2,
#  'civil': 1,
#  'hobble': 1,
#  'hot': 16,
#  'pathetic': 10,
#  'surly': 4,
#  'nose': 2,
#  'chin': 1,
#  'internal': 2,
#  'young-un': 1,
#  'l': 2,
#  "mis'able": 2,
#  'gin': 1,
#  "'cause": 1,
#  'Last': 8,
#  'child': 5,
#  'stone': 2,
#  'cotton-bale': 2,
#  'ill-repressed': 2,
#  "'em": 1,
#  'affable': 1,
#  'consistent': 2,
#  'doggish': 1,
#  'similar': 5,
#  'fust': 1,
#  'tight': 3,
#  'snug': 1,
#  'necessary': 20,
#  'cross': 1,
#  'feelin': 1,
#  "p'isin": 1,
#  'professional': 1,
#  'hundred': 5,
#  'n': 2,
#  'relishin': 1,
#  'slow': 11,
#  'ten': 10,
#  'tremendous': 3,
#  'Suppose': 1,
#  'quite': 4,
#  'fifty': 8,
#  'flat': 9,
#  'sixteen': 3,
#  'onreasonable': 1,
#  'bush-whacking': 1,
#  'conciliatory': 3,
#  'good-natured': 11,
#  'greasy': 5,
#  'boy': 1,
#  'somewhere': 1,
#  "it's": 1,
#  'underground': 1,
#  'First': 1,
#  'shawl': 1,
#  'lucky': 1,
#  'visible': 1,
#  'lawful': 5,
#  'patriotic': 3,
#  'locomotive': 1,
#  'nineteenth': 1,
#  'high-sounding': 1,
#  'drefful': 5,
#  "'Hio": 2,
#  'uncommonly': 3,
#  'responsible': 2,
#  'hear': 2,
#  'Easy': 1,
#  "t'": 1,
#  'angry': 4,
#  'penitential': 1,
#  "l'man": 1,
#  'proper': 10,
#  'intimated': 1,
#  'political': 7,
#  'especial': 4,
#  'rakish': 1,
#  'free-and-easy': 4,
#  'apparent': 5,
#  'ancient': 4,
#  'chronic': 3,
#  'obvious': 2,
#  'persecuted': 2,
#  'prodigal': 1,
#  'conceivable': 1,
#  'mathematical': 1,
#  'picturesque': 2,
#  'fashionable': 4,
#  'immovable': 1,
#  'sententious': 1,
#  'rebuked': 1,
#  'youngerly': 2,
#  'sot': 3,
#  'enthusiastic': 2,
#  "what's": 1,
#  'persistent': 4,
#  'folks': 2,
#  'top': 4,
#  'contrar': 1,
#  'ary': 1,
#  'restive': 1,
#  'feller-citizens': 1,
#  'principle': 1,
#  'scase': 1,
#  '-141-': 1,
#  'cheerful': 9,
#  'well-brightened': 1,
#  'senatorial': 1,
#  'very': 1,
#  'admonitory': 1,
#  'frolicsome': 1,
#  'untold': 4,
#  'door-knob': 1,
#  'Mary': 5,
#  'tired': 7,
#  'half-open': 1,
#  'tiresome': 3,
#  'downright': 3,
#  'unchristian': 4,
#  'reckless': 1,
#  'mild': 3,
#  'peach-blow': 1,
#  'sweetest': 1,
#  'moderate-sized': 1,
#  'moderate': 3,
#  'unusually': 1,
#  'sympathetic': 3,
#  'alarming': 1,
#  'inexplicable': 2,
#  'reverent': 1,
#  'several': 18,
#  'graceless': 1,
#  'crazy': 1,
#  'determined': 2,
#  'shameful': 4,
#  'abominable': 6,
#  'interesting': 5,
#  'naked': 7,
#  'accessible': 1,
#  'indefensible': 1,
#  'defenceless': 3,
#  'painful': 6,
#  'duty-it': 1,
#  '-146-': 1,
#  'whimsical': 1,
#  'slender': 2,
#  'torn': 3,
#  'frozen': 3,
#  'despised': 2,
#  'aspect': 1,
#  'domestic': 14,
#  'restorative': 1,
#  'Sure': 2,
#  "tol'able": 5,
#  'a-askin': 1,
#  'unrelaxing': 1,
#  'vigilant': 1,
#  'rested': 1,
#  'awake': 3,
#  'heart-broken': 6,
#  'agitated': 2,
#  'To-night': 3,
#  'unexpected': 1,
#  'pocket-handkerchiefs': 1,
#  'wry': 1,
#  'grown': 1,
#  'superficial': 1,
#  'apathetic': 1,
#  'Pish': 1,
#  'to-morrow': 7,
#  'fish': 1,
#  'confounded': 2,
#  'liege': 1,
#  "lord's": 1,
#  'cheap': 1,
#  'bed-room': 1,
#  'significant': 3,
#  'worn': 5,
#  'toy': 1,
#  'heart-break': 2,
#  'substantial': 2,
#  'sorrowful': 3,
#  'distressed': 6,
#  'delicate': 7,
#  'lost': 3,
#  'outcast': 1,
#  'serviceable': 1,
#  'work-table': 1,
#  'needle': 2,
#  'thimble': 3,
#  'twelve': 1,
#  'stringent': 1,
#  'immortal': 13,
#  'sentimental': 1,
#  'bold': 13,
#  '-156-': 1,
#  'imploring': 2,
#  'sad': 15,
#  'noble': 17,
#  'generous': 14,
#  'honorable': 3,
#  'continuous': 2,
#  'eastern': 2,
#  'unfathomable': 1,
#  'es': 1,
#  'accurate': 1,
#  'down-hill': 1,
#  'ineffectual': 2,
#  'outside': 2,
#  'back': 11,
#  'incredible': 2,
#  'firm': 2,
#  'despairing': 2,
#  'Western': 1,
#  'respectful': 7,
#  'inconsiderable': 1,
#  'tall': 15,
#  'sandy': 3,
#  'tousled': 1,
#  'dismal': 1,
#  'mystified': 1,
#  'gigantic': 5,
#  'retired': 2,
#  'Weary': 1,
#  'gal': 2,
#  'goodly': 5,
#  'healthy': 7,
#  "havin'": 1,
#  'ere': 1,
#  'Greek': 3,
#  'frisky': 1,
#  'ten-dollar': 1,
#  '-162-': 1,
#  'table': 3,
#  'ironing-cloth': 1,
#  'scrupulous': 5,
#  'unhappy': 5,
#  'smooth': 7,
#  "S'pose": 1,
#  'thine': 1,
#  'thar': 3,
#  '-164-': 1,
#  'stubborn': 1,
#  'sparrow': 1,
#  'instinctive': 5,
#  'local': 1,
#  'unknown': 8,
#  'unaffected': 2,
#  'frightful': 8,
#  '-165-': 1,
#  'missionary': 9,
#  'unenterprising': 1,
#  'heroic': 3,
#  'dread': 4,
#  "husband's": 1,
#  'mysterious': 12,
#  'extreme': 2,
#  'tossed': 1,
#  'act': 1,
#  'imperious': 3,
#  'utmost': 4,
#  'clamorous': 1,
#  'averted': 2,
#  'smothered': 6,
#  'unnecessary': 2,
#  'driving': 1,
#  "wife's": 1,
#  'half-slumbering': 1,
#  'manly': 2,
#  'unpleasant': 3,
#  'dusty': 3,
#  'past': 16,
#  '-170-': 1,
#  'stupid': 4,
#  'drunken': 3,
#  'sugar': 1,
#  'nasty': 1,
#  'mean': 10,
#  "'feard": 1,
#  'gettin': 2,
#  'foolish': 10,
#  'sich': 3,
#  'wilful': 3,
#  "'spectful": 1,
#  'first-rater': 1,
#  'Uncle': 1,
#  'meaner': 1,
#  'buyin': 1,
#  'ashamed': 1,
#  'good-by': 3,
#  'stiff': 2,
#  'boyish': 1,
#  'precious': 7,
#  '-174-': 1,
#  'fa': 1,
#  'superfluous': 1,
#  'inaccurate': 1,
#  '-175-': 1,
#  'drizzly': 1,
#  'raw-boned': 1,
#  'vast': 3,
#  'shot-pouches': 1,
#  'game-bags': 1,
#  'hunting-dogs': 1,
#  'long-legged': 2,
#  'muddy': 3,
#  'favorable': 1,
#  'western': 3,
#  'loose-jointed': 1,
#  'enormous': 3,
#  "man's": 1,
#  'republican': 6,
#  'wide-awake': 1,
#  'Shakespearean': 1,
#  'calico': 1,
#  'damp': 2,
#  'transmitted': 1,
#  'nonchalant': 2,
#  'jovial': 1,
#  'fussy': 1,
#  'honorary': 1,
#  'brotherly': 1,
#  'long-sided': 1,
#  '-178-': 1,
#  'military': 3,
#  'sufficient': 6,
#  'brown': 8,
#  'satisfactory': 1,
#  'related': 1,
#  'cumbrous': 1,
#  'Such': 10,
#  'half-dozen': 1,
#  'ingenious': 2,
#  'coarse-looking': 1,
#  '-180-': 1,
#  'Bright': 1,
#  'one-horse': 1,
#  'well-dressed': 2,
#  'gentlemanly': 5,
#  'servant': 3,
#  'rainy': 1,
#  'Spanish': 3,
#  'expressive': 1,
#  'close-curling': 1,
#  'well-formed': 2,
#  'admirable': 3,
#  'finely-formed': 1,
#  'careless': 11,
#  'obsequious': 2,
#  'male': 1,
#  'unconcerned': 2,
#  'blank': 3,
#  'newmade': 1,
#  'European': 1,
#  'indomitable': 1,
#  'Spanish-looking': 1,
#  'away-leaving': 1,
#  'unscriptural': 1,
#  'apostle': 1,
#  "you'd": 1,
#  'stray': 6,
#  '-185-': 1,
#  'fuzzy': 1,
#  'grateful': 1,
#  'infernal': 4,
#  'shoot': 1,
#  'north': 3,
#  ...}

# %%
len(c)
# Out:
# 2551
